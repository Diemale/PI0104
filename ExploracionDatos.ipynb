# %% [markdown]
# ### Exploración de datos

# %%
import pandas as pd

# %%
datos = pd.read_csv('C:\\Users\\diego\\Desktop\\PI01DTS04\\PI01_DATA_ENGINEERING\\DatasetsNew\\producto.csv', 
                      index_col=False, delimiter = ',')

# %%
del datos['categoria1']
del datos['categoria2']
del datos['categoria3']

# %%
datos
# Out:
#           idProducto        marca  \
# 0      0000000001663   LA ANÓNIMA
# 1      0000000002288   LA ANÓNIMA
# 2      0000000205870    SIN MARCA
# 3      0000000205894    SIN MARCA
# 4      0000000205955    SIN MARCA
# ...              ...          ...
# 72033  9569753142128  DELI-SITAS
# 72034  9795403001143         MAYO
# 72035  9990385651922         DANA
# 72036  9990385651939         DANA
# 72037  9990385651946         DANA
#
#                                                   nombre presentacion
# 0                        Radicheta Atada La Anonima 1 Un       1.0 un
# 1                          Perejil Atado La Anonima 1 Un       1.0 un
# 2                                       Ojo de Bife 1 Kg       1.0 kg
# 3                      Milanesa de Peceto Novillito 1 Kg       1.0 kg
# 4                             Chiquizuela Novillito 1 Kg       1.0 kg
# ...                                                  ...          ...
# ...

# %%
duplicate = datos[datos.duplicated(['idProducto'])]

# %%
print(duplicate)
# Out:
# Empty DataFrame
# Columns: [idProducto, marca, nombre, presentacion]
# Index: []

# %%
dupPorColumnas = datos[datos.duplicated(['marca','nombre','presentacion'])]

# %%
dupPorColumnas
# Out:
#               idProducto               marca  \
# 124        0000075068684              REXONA
# 282        0000077935861               SEDAL
# 293        0000077940254               SEDAL
# 314        0000077942388             BELDENT
# 318        0000077942630               SEDAL
# ...                  ...                 ...
# 72012  9-3-0000000994002           SIN MARCA
# 72013  9-3-0000000995696        PAMPA CHEESE
# 72014  9-3-0000000997096           SIN MARCA
# 72015  9-3-0000000997126           SIN MARCA
# 72016  9-3-0000000999137  LA HACIEDA BANDEJA
#
#                                                   nombre presentacion
# 124        Desodorante en Roll On Sport Men Rexona 50 Ml      50.0 ml
# 282                    Shampoo Crema Balance Sedal 10 Ml      10.0 ml
# 293                    Shampoo Crema Balance Sedal 10 Ml      10.0 ml
# 314            Chicles Sabor Menta Blister Beldent 10 Gr      10.0 gr
# ...

# %%
# Esto muestra que existen productos idénticos con distinto idProducto. Pero podrían ser vendidos por distintas cadenas
# y eso ocasionaría una falla en la carga de precios. Sin mayor información al respecto prefiero dejar los registros
# en lugar de borrarlos.

# %%
#Quito los duplicados eligiengo un subconjunto de columnas

# %%
datos = datos.drop_duplicates(subset=['marca', 'nombre','presentacion'], keep='last')

# %%
datos
# Out:
#           idProducto        marca  \
# 0      0000000001663   LA ANÓNIMA
# 1      0000000002288   LA ANÓNIMA
# 3      0000000205894    SIN MARCA
# 7      0000000206044    SIN MARCA
# 8      0000000206051    SIN MARCA
# ...              ...          ...
# 72033  9569753142128  DELI-SITAS
# 72034  9795403001143         MAYO
# 72035  9990385651922         DANA
# 72036  9990385651939         DANA
# 72037  9990385651946         DANA
#
#                                                   nombre presentacion
# 0                        Radicheta Atada La Anonima 1 Un       1.0 un
# 1                          Perejil Atado La Anonima 1 Un       1.0 un
# 3                      Milanesa de Peceto Novillito 1 Kg       1.0 kg
# 7                Falda Deshuesada Novillito Bandeja 1 Kg       1.0 kg
# 8                                Carne Picada Comun 1 Kg       1.0 kg
# ...                                                  ...          ...
# ...

# %%
datos.loc[datos['nombre'] == 'Shampoo Crema Balance Sedal 10 Ml']
# Out:
#         idProducto  marca                             nombre presentacion
# 320  0000077942654  SEDAL  Shampoo Crema Balance Sedal 10 Ml      10.0 ml

# %%
datos = datos.dropna()

# %%
datos
# Out:
#           idProducto        marca  \
# 0      0000000001663   LA ANÓNIMA
# 1      0000000002288   LA ANÓNIMA
# 3      0000000205894    SIN MARCA
# 7      0000000206044    SIN MARCA
# 8      0000000206051    SIN MARCA
# ...              ...          ...
# 72033  9569753142128  DELI-SITAS
# 72034  9795403001143         MAYO
# 72035  9990385651922         DANA
# 72036  9990385651939         DANA
# 72037  9990385651946         DANA
#
#                                                   nombre presentacion
# 0                        Radicheta Atada La Anonima 1 Un       1.0 un
# 1                          Perejil Atado La Anonima 1 Un       1.0 un
# 3                      Milanesa de Peceto Novillito 1 Kg       1.0 kg
# 7                Falda Deshuesada Novillito Bandeja 1 Kg       1.0 kg
# 8                                Carne Picada Comun 1 Kg       1.0 kg
# ...                                                  ...          ...
# ...

# %%
datos = pd.read_csv('C:\\Users\\diego\\Desktop\\PI01DTS04\\PI01_DATA_ENGINEERING\\Datasets\\precios_semana_20200413.csv', 
                      index_col=False, delimiter = ',')

# %%
datos
# Out:
#         precio    producto_id sucursal_id
# 0        29.90  0000000001663     2-1-014
# 1        29.90  0000000002288     2-1-032
# 2        39.90  0000000002288     2-1-096
# 3       499.99  0000000205870     9-1-686
# 4       519.99  0000000205870     9-2-248
# ...        ...            ...         ...
# 472161  139.99  9569753142128      25-1-1
# 472162   34.99  9795403001143      25-1-1
# 472163  312.50  9990385651922       5-1-3
# 472164  312.50  9990385651939       5-1-3
# 472165  198.90  9990385651946       5-1-3
#
# [472166 rows x 3 columns]

# %%
datos['precio'].max()
# Out:
# 34417.15

# %%
#datos.describe()

# %%
datos.loc[datos['precio'] == 34417.15]
# Out:
#          precio    producto_id sucursal_id
# 30971  34417.15  5000299284926    12-1-185

# %%
nulos = datos.isna().sum().sum()

# %%
dupPorColumnas = datos[datos.duplicated(['precio','producto_id','sucursal_id'])]

# %%
dupPorColumnas
# Out:
#          precio    producto_id sucursal_id
# 246748      NaN            NaN         NaN
# 246794    65.90  7791290780170      50-1-2
# 246795    65.85  7791290780170       6-1-9
# 246796    65.85  7791290780170      6-2-21
# 246822    65.90  7791290780170      50-1-2
# 246823    65.85  7791290780170       6-1-9
# 246824    65.85  7791290780170      6-2-21
# 246882      NaN            NaN         NaN
# 246978      NaN            NaN         NaN
# 247033      NaN            NaN         NaN
# 247167      NaN            NaN         NaN
# 247310      NaN            NaN         NaN
# 247404      NaN            NaN         NaN
# 247405      NaN            NaN         NaN
# 247520      NaN            NaN         NaN
# 247660      NaN            NaN         NaN
# 459373      NaN            NaN         NaN
# 459462  1349.90  7898024397205      18-1-6
# 459514   289.99  0000000216616     9-1-686
# 459515   249.00  0000000221184     9-1-690
# 459516   259.00  0000000221184     9-2-583
# ...

# %%
len(dupPorColumnas)
# Out:
# 32
